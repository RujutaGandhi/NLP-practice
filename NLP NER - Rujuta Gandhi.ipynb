# %% [markdown]
# # NLP NER - Rujuta Gandhi
#
# You have been provided with a pickle file, containing the 100 news articles about Caterpillar.  Identify what companies are mentioned most frequently in the news along with Caterpillar.
#
# - pd.read_pickle(directory+'news_cat.pkl')
# - Discard non-English results
# - Identify what companies are mentioned most frequently along with Caterpillar (in both title and the body of the article)
# - Show a table or chart with your top-20 companies (sorted in the descending order)

# %% [markdown]
# ### Import Library, File, English Only Results

# %%
import pyforest
import pandas as pd

# %%
import spacy 
from spacy import displacy
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#SpaCy 2.x brough significant speed and accuracy improvements
spacy.__version__
# Out:
# '2.2.3'

# %%
df = pd.read_pickle(r"C:\Users\gandh\Google Drive\UChicago\11_Quarter 10\Assignments\Assignment 5\news_cat.pkl")

# %%
df.head()
# Out:
#                          crawled language  \
# 0  2018-01-30T23:03:51.004+02:00  english
# 1  2018-01-30T23:06:46.024+02:00  english
# 2  2018-01-30T23:18:35.023+02:00  english
# 3  2018-01-30T23:20:54.012+02:00  english
# 4  2018-01-30T23:28:30.000+02:00  english
#
#                                                 text  \
# 0  by Abhishek K Global Telehandler Market 2023 D...
# 1  favorite this post 2014 Caterpillar 314E LCR h...
# 2  By: MAX NISEN The Amazon health care threat ha...
# 3  QR Code Link to This Post MONTHLY PUBLIC AUCTI...
# 4  QR Code Link to This Post 2007 CATERPILLAR D4G...
#
#                                                title
# 0  Global Telehandler Market 2023 Demand by Segme...
# 1                          2014 Caterpillar 314E LCR
# 2  Amazon, Berkshire, JPMorgan health announcemen...
# 3  2005 Caterpillar CB534D Tandem Vibratory Rolle...
# 4  2007 CATERPILLAR D4G LGP CAB SCREEN/SWEEPS - O...

# %%
df.shape
# Out:
# (100, 4)

# %%
df.language.value_counts()
# Out:
# english    100
# Name: language, dtype: int64

# %% [markdown]
# #### The file already has English only results

# %% [markdown]
# df = df[df.language=='english']
# df.head()

# %%
df = df.drop(columns=['crawled','language'])

# %% [markdown]
# #### Load Spacy Model

# %%
# Load SpaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# #### Identify what companies are mentioned most frequently along with Caterpillar (in both title and the body of the article)
# - Get text and title in the same columns
# - Keep rows only if they contain some version of Caterpillar

# %%
text_updated = pd.DataFrame(df['text'][df['text'].str.contains('Cat|CAT')==True]).rename(columns={"text": "title_text"}).reset_index(drop=True)
text_updated
# Out:
#                                            title_text
# 0   by Abhishek K Global Telehandler Market 2023 D...
# 1   favorite this post 2014 Caterpillar 314E LCR h...
# 2   QR Code Link to This Post MONTHLY PUBLIC AUCTI...
# 3   QR Code Link to This Post 2007 CATERPILLAR D4G...
# 4   Elite Wealth Management Inc. Acquires Shares o...
# ..                                                ...
# 92  What to Expect From Caterpillar Inc. in 2018 J...
# 93  transmission: other QR Code Link to This Post ...
# 94  One year after Caterpillar's headquarters anno...
# 95  1,613 Shares in Caterpillar Inc. (NYSE:CAT) Pu...
# 96  Tweet \nWeatherly Asset Management L. P. reduc...
#
# [97 rows x 1 columns]

# %%
title_updated = pd.DataFrame(df['title'][df['title'].str.contains('Cat|CAT')==True]).rename(columns={"title": "title_text"}).reset_index(drop=True)
title_updated.shape
# Out:
# (53, 1)

# %%
frame=[title_updated,text_updated]
text_title = pd.concat(frame).reset_index(drop=True)
text_title.head()
# Out:
#                                           title_text
FG Advisory LLC Takes $623,000 Position in Caterpillar Inc. (CAT) | FineMark National Bank & Trust Has $1.36 Million Holdings in Caterpillar Inc. (CAT) | Oakmont Partners LLC Invests $387,000 in Caterpillar Inc. (CAT) Stock | Regentatlantic Capital LLC Sells 913 Shares of Caterpillar Inc. (NYSE:CAT) | Louisiana State Employees Retirement System Has $5.67 Million Position in Caterpillar Inc. (CAT) | Convergence Investment Partners LLC Purchases New Position in Caterpillar Inc. (CAT) | 440 Investment Group LLC Invests $303,000 in Caterpillar Inc. (NYSE:CAT) | Caterpillar Inc. (NYSE:CAT) Shares Sold by Partnervest Advisory Services LLC | What to Expect From Caterpillar Inc. in 2018 | What to Expect From Caterpillar Inc. in 2018 | One year after Caterpillar's headquarters announcement, Peoria progresses | 1,613 Shares in Caterpillar Inc. (NYSE:CAT) Purchased by Summit X LLC | Caterpillar Inc. (CAT) Holdings Cut by Weatherly Asset Management L. P. | by Abhishek K Global Telehandler Market 2023 Demand by Se ...

# %% [markdown]
# #### Get Organization list with NER
# - Remove other label types

# %%
entities = []
labels = []

for ent in text_title.ents:
    entities.append(ent)
    labels.append(ent.label_)
    
tt_entities = pd.DataFrame({'Entities':entities,'Labels':labels})

tt_entities.head(20)
# Out:
#                Entities    Labels
# 0                (2014)  CARDINAL
# 1                (314E)  CARDINAL
# 2                 (LCR)       ORG
# 3                (2005)      DATE
# 4                (2007)      DATE
# 5              (SWEENY)       ORG
# 6                  (TX)       ORG
# 7               (65999)      DATE
# 8               (2,191)  CARDINAL
# 9   (Caterpillar, Inc.)       ORG
# 10                (CAT)       ORG
# 11       (Triple, Mast)       GPE
# 12           (Claymont)       ORG
# 13               (4499)     MONEY
# 14           (MICHIGAN)       ORG
# 15                (Cat)       ORG
# 16  (Caterpillar, Inc.)       ORG
# 17                (CAT)       ORG
# 18   (One, year, later)      DATE
# 19        (Caterpillar)       ORG

# %%
filt = tt_entities[(tt_entities['Labels']=='ORG')].reset_index(drop=True).drop('Labels',axis=1)

# %%
filt
# Out:
#                    Entities
# 0                     (LCR)
# 1                  (SWEENY)
# 2                      (TX)
# 3       (Caterpillar, Inc.)
# 4                     (CAT)
# ...                     ...
# 2138  (HoldingsChannel.com)
# 2139    (Caterpillar, Inc.)
# 2140                 (NYSE)
# 2141          (Caterpillar)
# 2142          (Caterpillar)
#
# [2143 rows x 1 columns]

# %% [markdown]
# #### Show a table or chart with your top-20 companies (sorted in the descending order)
# - drop any occurrences of Caterpillar in any form

# %%
filt = filt.astype('str')

# %%
final = pd.DataFrame(filt['Entities'][filt['Entities'].str.contains('Cat|CAT')==False]).reset_index(drop=True)
entity_counts = pd.DataFrame(final.groupby('Entities')['Entities'].count().sort_values(ascending = False))
entity_counts.head(20)
# Out:
#                                         Entities
# Entities
# NYSE                                          63
# SEC                                           23
# Amazon                                        22
# Vista                                         22
# Resource Industries                           21
# Energy & Transportation                       19
# EPS                                           18
# Construction Industries                       18
# Company                                       18
# Financial Products                            18
# Vetr                                          16
# Citigroup                                     13
# Rolling Stock                                 12
# Dow                                           12
# the Securities and Exchange Commission        11
# Apple                                         10
# Acrospire Investment Management LLC           10
# Vista Partners                                10
# Samsung                                       10
# The Motley Fool                                9
